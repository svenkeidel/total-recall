# %%
import os
import sys

module_path = os.path.abspath(os.path.join('.', 'src')) 
sys.path.append(module_path)

from parse import read_results
from compute import *

data = read_results(os.path.abspath('target'))
# data = columns_to_rows(data)

df = data.sort_values(by=['project', 'framework', 'algo', 'scope', 'package'])
# Out:
#     project framework     algo  scope  package  true_positive  false_positive  \
# 526   axion      Doop    0-CFA  edges  package             16             184
# 472   axion      OPAL  0-1-CFA  edges  package             57              34
# 442   axion      OPAL    0-CFA  edges  package             57              34
# 478   axion      OPAL  1-0-CFA  edges  package             57              34
# 454   axion      OPAL  1-1-CFA  edges  package             57              34
# 484   axion      OPAL      CHA  edges  package           3347           59840
# 460   axion      OPAL      CTA  edges  package             59              34
# 490   axion      OPAL      FTA  edges  package             59              34
# 448   axion      OPAL      RTA  edges  package             59              34
# 466   axion      OPAL      XTA  edges  package             59              34
# 550   axion      Soot      CHA  edges  package           3654           47774
# 532   axion      Soot      RTA  edges  package           3571           37919
# 544   axion      Soot    SPARK  edges  package           3000            5267
# 538   axion      Soot      VTA  edges  package           3464           24801
# 424   axion    SootUp    0-CFA  edges  package             53              42
# 418   axion    SootUp    1-CFA  edges  package             48              39
# 436   axion    SootUp      CHA  edges  package             53              65
# 430   axion    SootUp      RTA  edges  package             53              59
# 562   axion      Taie      CHA  edges  package             32              93
# 556   axion      Taie      PTA  edges  package             32              59
# 514   axion      WALA  0-1-CFA  edges  package           3369            5020
# 502   axion      WALA    0-CFA  edges  package           3369            5048
# 496   axion      WALA    1-CFA  edges  package           3362            4615
# 520   axion      WALA      CHA  edges  package           3598           57630
# 508   axion      WALA      RTA  edges  package           3535           21236
# 256   batik      Doop    0-CFA  edges  package             24             580
# 202   batik      OPAL  0-1-CFA  edges  package           5088            5123
# 178   batik      OPAL    0-CFA  edges  package           1584            1118
# 208   batik      OPAL  1-0-CFA  edges  package           1582            1106
# 190   batik      OPAL  1-1-CFA  edges  package           5085            5066
# 214   batik      OPAL      CHA  edges  package          12138          224128
# 220   batik      OPAL      FTA  edges  package           1839            1507
# 184   batik      OPAL      RTA  edges  package          10581           25848
# 196   batik      OPAL      XTA  edges  package           1837            1498
# 280   batik      Soot      CHA  edges  package          12400          204274
# 262   batik      Soot      RTA  edges  package          11833          154150
# 274   batik      Soot    SPARK  edges  package          10778           27975
# 268   batik      Soot      VTA  edges  package          11829          101771
# 160   batik    SootUp    0-CFA  edges  package           3774            6311
# 154   batik    SootUp    1-CFA  edges  package           3774            6069
# 172   batik    SootUp      CHA  edges  package           7392           57971
# 166   batik    SootUp      RTA  edges  package           6575           22883
# 292   batik      Taie      CHA  edges  package           4280           73673
# 286   batik      Taie      PTA  edges  package           4026           26766
# 244   batik      WALA  0-1-CFA  edges  package           5126            8340
# 232   batik      WALA    0-CFA  edges  package           5127            8834
# 226   batik      WALA    1-CFA  edges  package           5126            7447
# 250   batik      WALA      CHA  edges  package           9087          120833
# 238   batik      WALA      RTA  edges  package           6372           36733
# 376  hsqldb      Doop    0-CFA  edges  package              7              82
# 352  hsqldb      OPAL  0-1-CFA  edges  package            610             587
# 322  hsqldb      OPAL    0-CFA  edges  package            613             586
# 358  hsqldb      OPAL  1-0-CFA  edges  package            613             586
# 334  hsqldb      OPAL  1-1-CFA  edges  package            610             587
# 364  hsqldb      OPAL      CHA  edges  package          13172          193987
# 340  hsqldb      OPAL      CTA  edges  package            623             675
# 370  hsqldb      OPAL      FTA  edges  package            621             631
# 328  hsqldb      OPAL      RTA  edges  package            627             690
# 346  hsqldb      OPAL      XTA  edges  package            621             627
# 400  hsqldb      Soot      CHA  edges  package          13279           90171
# 382  hsqldb      Soot      RTA  edges  package          11674           64815
# 394  hsqldb      Soot    SPARK  edges  package          11361           23672
# 388  hsqldb      Soot      VTA  edges  package          11431           43224
# 304  hsqldb    SootUp    0-CFA  edges  package            505             835
# 298  hsqldb    SootUp    1-CFA  edges  package            505             826
# 316  hsqldb    SootUp      CHA  edges  package            449            1040
# 310  hsqldb    SootUp      RTA  edges  package            449            1040
# 412  hsqldb      Taie      CHA  edges  package            291            2830
# 406  hsqldb      Taie      PTA  edges  package            312            1030
# 676   jasml      Doop    0-CFA  edges  package             20               0
# 622   jasml      OPAL  0-1-CFA  edges  package            838             109
# 592   jasml      OPAL    0-CFA  edges  package            838             109
# 628   jasml      OPAL  1-0-CFA  edges  package            838             109
# 604   jasml      OPAL  1-1-CFA  edges  package            838             109
# 634   jasml      OPAL      CHA  edges  package            860             422
# 610   jasml      OPAL      CTA  edges  package            840             112
# 640   jasml      OPAL      FTA  edges  package            838             110
# 598   jasml      OPAL      RTA  edges  package            841             112
# 616   jasml      OPAL      XTA  edges  package            838             110
# 700   jasml      Soot      CHA  edges  package            912             653
# 682   jasml      Soot      RTA  edges  package            911             651
# 694   jasml      Soot    SPARK  edges  package            911             517
# 688   jasml      Soot      VTA  edges  package            911             562
# 574   jasml    SootUp    0-CFA  edges  package            840             190
# 568   jasml    SootUp    1-CFA  edges  package            840             190
# 586   jasml    SootUp      CHA  edges  package            775             245
# 580   jasml    SootUp      RTA  edges  package            775             245
# 712   jasml      Taie      CHA  edges  package            405             511
# 706   jasml      Taie      PTA  edges  package            414             607
# 664   jasml      WALA  0-1-CFA  edges  package            908             113
# 652   jasml      WALA    0-CFA  edges  package            908             124
# 646   jasml      WALA    1-CFA  edges  package            908             113
# 670   jasml      WALA      CHA  edges  package            906            1136
# 658   jasml      WALA      RTA  edges  package            908             474
# 112  xerces      Doop    0-CFA  edges  package              0               0
# 58   xerces      OPAL  0-1-CFA  edges  package            861            3115
# 28   xerces      OPAL    0-CFA  edges  package              0               0
# 64   xerces      OPAL  1-0-CFA  edges  package              0               0
# 40   xerces      OPAL  1-1-CFA  edges  package            861            3094
# 70   xerces      OPAL      CHA  edges  package           2893           76425
# 46   xerces      OPAL      CTA  edges  package              0               0
# 76   xerces      OPAL      FTA  edges  package              0               0
# 34   xerces      OPAL      RTA  edges  package              0               0
# 52   xerces      OPAL      XTA  edges  package              0               0
# 136  xerces      Soot      CHA  edges  package           2932           62081
# 118  xerces      Soot      RTA  edges  package           2844           43162
# 130  xerces      Soot    SPARK  edges  package              0               0
# 124  xerces      Soot      VTA  edges  package            410           13661
# 10   xerces    SootUp    0-CFA  edges  package              0               0
# 4    xerces    SootUp    1-CFA  edges  package              0               0
# 22   xerces    SootUp      CHA  edges  package           1538           24200
# 16   xerces    SootUp      RTA  edges  package              0               0
# 148  xerces      Taie      CHA  edges  package              0               0
# 142  xerces      Taie      PTA  edges  package              0               0
# 100  xerces      WALA  0-1-CFA  edges  package              0               0
# 88   xerces      WALA    0-CFA  edges  package              0               0
# 82   xerces      WALA    1-CFA  edges  package              0               0
# 106  xerces      WALA      CHA  edges  package              0              82
# 94   xerces      WALA      RTA  edges  package              0               0
#
#      false_negative  precision    recall  f1-score
# 526            3865   0.080000  0.004123  0.007841
# 472            3824   0.626374  0.014687  0.028701
# 442            3824   0.626374  0.014687  0.028701
# 478            3824   0.626374  0.014687  0.028701
# 454            3824   0.626374  0.014687  0.028701
# 484             534   0.052970  0.862407  0.099809
# 460            3822   0.634409  0.015202  0.029693
# 490            3822   0.634409  0.015202  0.029693
# 448            3822   0.634409  0.015202  0.029693
# 466            3822   0.634409  0.015202  0.029693
# 550             227   0.071051  0.941510  0.132130
# 532             310   0.086069  0.920124  0.157413
# 544             881   0.362889  0.772997  0.493908
# 538             417   0.122554  0.892553  0.215517
# 424            3828   0.557895  0.013656  0.026660
# 418            3833   0.551724  0.012368  0.024194
# 436            3828   0.449153  0.013656  0.026507
# 430            3828   0.473214  0.013656  0.026546
# 562            3849   0.256000  0.008245  0.015976
# 556            3849   0.351648  0.008245  0.016113
# 514             512   0.401597  0.868075  0.549144
# 502             512   0.400261  0.868075  0.547894
# 496             519   0.421462  0.866272  0.567043
# 520             283   0.058764  0.927081  0.110522
# 508             346   0.142707  0.910848  0.246754
# 256           13013   0.039735  0.001841  0.003519
# 202            7949   0.498286  0.390274  0.437715
# 178           11453   0.586232  0.121500  0.201283
# 208           11455   0.588542  0.121347  0.201208
# 190            7952   0.500936  0.390044  0.438589
# 214             899   0.051374  0.931042  0.097375
# 220           11198   0.549611  0.141060  0.224501
# 184            2456   0.290455  0.811613  0.427809
# 196           11200   0.550825  0.140907  0.224408
# 280             637   0.057229  0.951139  0.107962
# 262            1204   0.071290  0.907647  0.132198
# 274            2259   0.278120  0.826724  0.416219
# 268            1208   0.104129  0.907341  0.186817
# 160            9263   0.374219  0.289484  0.326442
# 154            9263   0.383420  0.289484  0.329895
# 172            5645   0.113092  0.567002  0.188571
# 166            6462   0.223199  0.504334  0.309448
# 292            8757   0.054905  0.328296  0.094076
# 286            9011   0.130748  0.308813  0.183714
# 244            7911   0.380662  0.393189  0.386824
# 232            7910   0.367237  0.393265  0.379806
# 226            7911   0.407699  0.393189  0.400312
# 250            3950   0.069943  0.697016  0.127129
# 238            6665   0.147825  0.488763  0.226996
# 376           13586   0.078652  0.000515  0.001023
# 352           12983   0.509607  0.044876  0.082488
# 322           12980   0.511259  0.045097  0.082883
# 358           12980   0.511259  0.045097  0.082883
# 334           12983   0.509607  0.044876  0.082488
# 364             421   0.063584  0.969028  0.119338
# 340           12970   0.479969  0.045832  0.083675
# 370           12972   0.496006  0.045685  0.083665
# 328           12966   0.476082  0.046127  0.084105
# 346           12972   0.497596  0.045685  0.083687
# 400             314   0.128362  0.976900  0.226908
# 382            1919   0.152623  0.858824  0.259186
# 394            2232   0.324294  0.835798  0.467281
# 388            2162   0.209148  0.840948  0.334984
# 304           13088   0.376866  0.037151  0.067635
# 298           13088   0.379414  0.037151  0.067676
# 316           13144   0.301545  0.033032  0.059541
# 310           13144   0.301545  0.033032  0.059541
# 412           13302   0.093239  0.021408  0.034821
# 406           13281   0.232489  0.022953  0.041781
# 676             954   1.000000  0.020534  0.040241
# 622             136   0.884900  0.860370  0.872462
# 592             136   0.884900  0.860370  0.872462
# 628             136   0.884900  0.860370  0.872462
# 604             136   0.884900  0.860370  0.872462
# 634             114   0.670827  0.882957  0.762411
# 610             134   0.882353  0.862423  0.872274
# 640             136   0.883966  0.860370  0.872008
# 598             133   0.882476  0.863450  0.872859
# 616             136   0.883966  0.860370  0.872008
# 700              62   0.582748  0.936345  0.718393
# 682              63   0.583227  0.935318  0.718454
# 694              63   0.637955  0.935318  0.758535
# 688              63   0.618466  0.935318  0.744585
# 574             134   0.815534  0.862423  0.838323
# 568             134   0.815534  0.862423  0.838323
# 586             199   0.759804  0.795688  0.777332
# 580             199   0.759804  0.795688  0.777332
# 712             569   0.442140  0.415811  0.428571
# 706             560   0.405485  0.425051  0.415038
# 664              66   0.889324  0.932238  0.910276
# 652              66   0.879845  0.932238  0.905284
# 646              66   0.889324  0.932238  0.910276
# 670              68   0.443683  0.930185  0.600796
# 658              66   0.657019  0.932238  0.770798
# 112            3062   0.000000  0.000000  0.000000
# 58             2201   0.216549  0.281189  0.244672
# 28             3062   0.000000  0.000000  0.000000
# 64             3062   0.000000  0.000000  0.000000
# 40             2201   0.217699  0.281189  0.245404
# 70              169   0.036473  0.944807  0.070235
# 46             3062   0.000000  0.000000  0.000000
# 76             3062   0.000000  0.000000  0.000000
# 34             3062   0.000000  0.000000  0.000000
# 52             3062   0.000000  0.000000  0.000000
# 136             130   0.045099  0.957544  0.086140
# 118             218   0.061818  0.928805  0.115921
# 130            3062   0.000000  0.000000  0.000000
# 124            2652   0.029138  0.133899  0.047861
# 10             3062   0.000000  0.000000  0.000000
# 4              3062   0.000000  0.000000  0.000000
# 22             1524   0.059756  0.502286  0.106806
# 16             3062   0.000000  0.000000  0.000000
# 148            3062   0.000000  0.000000  0.000000
# 142            3062   0.000000  0.000000  0.000000
# 100            3062   0.000000  0.000000  0.000000
# 88             3062   0.000000  0.000000  0.000000
# 82             3062   0.000000  0.000000  0.000000
# 106            3062   0.000000  0.000000  0.000000
# 94             3062   0.000000  0.000000  0.000000

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[(df['scope'] == 'edges') & (df['package'] == 'package')])
# Out:
#     project framework     algo  scope  package  true_positive  false_positive  \
# 526   axion      Doop    0-CFA  edges  package             16             184
# 472   axion      OPAL  0-1-CFA  edges  package             57              34
# 442   axion      OPAL    0-CFA  edges  package             57              34
# 478   axion      OPAL  1-0-CFA  edges  package             57              34
# 454   axion      OPAL  1-1-CFA  edges  package             57              34
# 484   axion      OPAL      CHA  edges  package           3347           59840
# 460   axion      OPAL      CTA  edges  package             59              34
# 490   axion      OPAL      FTA  edges  package             59              34
# 448   axion      OPAL      RTA  edges  package             59              34
# 466   axion      OPAL      XTA  edges  package             59              34
# 550   axion      Soot      CHA  edges  package           3654           47774
# 532   axion      Soot      RTA  edges  package           3571           37919
# 544   axion      Soot    SPARK  edges  package           3000            5267
# 538   axion      Soot      VTA  edges  package           3464           24801
# 424   axion    SootUp    0-CFA  edges  package             53              42
# 418   axion    SootUp    1-CFA  edges  package             48              39
# 436   axion    SootUp      CHA  edges  package             53              65
# 430   axion    SootUp      RTA  edges  package             53              59
# 562   axion      Taie      CHA  edges  package             32              93
# 556   axion      Taie      PTA  edges  package             32              59
# 514   axion      WALA  0-1-CFA  edges  package           3369            5020
# 502   axion      WALA    0-CFA  edges  package           3369            5048
# 496   axion      WALA    1-CFA  edges  package           3362            4615
# 520   axion      WALA      CHA  edges  package           3598           57630
# 508   axion      WALA      RTA  edges  package           3535           21236
# 256   batik      Doop    0-CFA  edges  package             24             580
# 202   batik      OPAL  0-1-CFA  edges  package           5088            5123
# 178   batik      OPAL    0-CFA  edges  package           1584            1118
# 208   batik      OPAL  1-0-CFA  edges  package           1582            1106
# 190   batik      OPAL  1-1-CFA  edges  package           5085            5066
# 214   batik      OPAL      CHA  edges  package          12138          224128
# 220   batik      OPAL      FTA  edges  package           1839            1507
# 184   batik      OPAL      RTA  edges  package          10581           25848
# 196   batik      OPAL      XTA  edges  package           1837            1498
# 280   batik      Soot      CHA  edges  package          12400          204274
# 262   batik      Soot      RTA  edges  package          11833          154150
# 274   batik      Soot    SPARK  edges  package          10778           27975
# 268   batik      Soot      VTA  edges  package          11829          101771
# 160   batik    SootUp    0-CFA  edges  package           3774            6311
# 154   batik    SootUp    1-CFA  edges  package           3774            6069
# 172   batik    SootUp      CHA  edges  package           7392           57971
# 166   batik    SootUp      RTA  edges  package           6575           22883
# 292   batik      Taie      CHA  edges  package           4280           73673
# 286   batik      Taie      PTA  edges  package           4026           26766
# 244   batik      WALA  0-1-CFA  edges  package           5126            8340
# 232   batik      WALA    0-CFA  edges  package           5127            8834
# 226   batik      WALA    1-CFA  edges  package           5126            7447
# 250   batik      WALA      CHA  edges  package           9087          120833
# 238   batik      WALA      RTA  edges  package           6372           36733
# 376  hsqldb      Doop    0-CFA  edges  package              7              82
# 352  hsqldb      OPAL  0-1-CFA  edges  package            610             587
# 322  hsqldb      OPAL    0-CFA  edges  package            613             586
# 358  hsqldb      OPAL  1-0-CFA  edges  package            613             586
# 334  hsqldb      OPAL  1-1-CFA  edges  package            610             587
# 364  hsqldb      OPAL      CHA  edges  package          13172          193987
# 340  hsqldb      OPAL      CTA  edges  package            623             675
# 370  hsqldb      OPAL      FTA  edges  package            621             631
# 328  hsqldb      OPAL      RTA  edges  package            627             690
# 346  hsqldb      OPAL      XTA  edges  package            621             627
# 400  hsqldb      Soot      CHA  edges  package          13279           90171
# 382  hsqldb      Soot      RTA  edges  package          11674           64815
# 394  hsqldb      Soot    SPARK  edges  package          11361           23672
# 388  hsqldb      Soot      VTA  edges  package          11431           43224
# 304  hsqldb    SootUp    0-CFA  edges  package            505             835
# 298  hsqldb    SootUp    1-CFA  edges  package            505             826
# 316  hsqldb    SootUp      CHA  edges  package            449            1040
# 310  hsqldb    SootUp      RTA  edges  package            449            1040
# 412  hsqldb      Taie      CHA  edges  package            291            2830
# 406  hsqldb      Taie      PTA  edges  package            312            1030
# 676   jasml      Doop    0-CFA  edges  package             20               0
# 622   jasml      OPAL  0-1-CFA  edges  package            838             109
# 592   jasml      OPAL    0-CFA  edges  package            838             109
# 628   jasml      OPAL  1-0-CFA  edges  package            838             109
# 604   jasml      OPAL  1-1-CFA  edges  package            838             109
# 634   jasml      OPAL      CHA  edges  package            860             422
# 610   jasml      OPAL      CTA  edges  package            840             112
# 640   jasml      OPAL      FTA  edges  package            838             110
# 598   jasml      OPAL      RTA  edges  package            841             112
# 616   jasml      OPAL      XTA  edges  package            838             110
# 700   jasml      Soot      CHA  edges  package            912             653
# 682   jasml      Soot      RTA  edges  package            911             651
# 694   jasml      Soot    SPARK  edges  package            911             517
# 688   jasml      Soot      VTA  edges  package            911             562
# 574   jasml    SootUp    0-CFA  edges  package            840             190
# 568   jasml    SootUp    1-CFA  edges  package            840             190
# 586   jasml    SootUp      CHA  edges  package            775             245
# 580   jasml    SootUp      RTA  edges  package            775             245
# 712   jasml      Taie      CHA  edges  package            405             511
# 706   jasml      Taie      PTA  edges  package            414             607
# 664   jasml      WALA  0-1-CFA  edges  package            908             113
# 652   jasml      WALA    0-CFA  edges  package            908             124
# 646   jasml      WALA    1-CFA  edges  package            908             113
# 670   jasml      WALA      CHA  edges  package            906            1136
# 658   jasml      WALA      RTA  edges  package            908             474
# 112  xerces      Doop    0-CFA  edges  package              0               0
# 58   xerces      OPAL  0-1-CFA  edges  package            861            3115
# 28   xerces      OPAL    0-CFA  edges  package              0               0
# 64   xerces      OPAL  1-0-CFA  edges  package              0               0
# 40   xerces      OPAL  1-1-CFA  edges  package            861            3094
# 70   xerces      OPAL      CHA  edges  package           2893           76425
# 46   xerces      OPAL      CTA  edges  package              0               0
# 76   xerces      OPAL      FTA  edges  package              0               0
# 34   xerces      OPAL      RTA  edges  package              0               0
# 52   xerces      OPAL      XTA  edges  package              0               0
# 136  xerces      Soot      CHA  edges  package           2932           62081
# 118  xerces      Soot      RTA  edges  package           2844           43162
# 130  xerces      Soot    SPARK  edges  package              0               0
# 124  xerces      Soot      VTA  edges  package            410           13661
# 10   xerces    SootUp    0-CFA  edges  package              0               0
# 4    xerces    SootUp    1-CFA  edges  package              0               0
# 22   xerces    SootUp      CHA  edges  package           1538           24200
# 16   xerces    SootUp      RTA  edges  package              0               0
# 148  xerces      Taie      CHA  edges  package              0               0
# 142  xerces      Taie      PTA  edges  package              0               0
# 100  xerces      WALA  0-1-CFA  edges  package              0               0
# 88   xerces      WALA    0-CFA  edges  package              0               0
# 82   xerces      WALA    1-CFA  edges  package              0               0
# 106  xerces      WALA      CHA  edges  package              0              82
# 94   xerces      WALA      RTA  edges  package              0               0
#
#      false_negative  precision    recall  f1-score
# 526            3865   0.080000  0.004123  0.007841
# 472            3824   0.626374  0.014687  0.028701
# 442            3824   0.626374  0.014687  0.028701
# 478            3824   0.626374  0.014687  0.028701
# 454            3824   0.626374  0.014687  0.028701
# 484             534   0.052970  0.862407  0.099809
# 460            3822   0.634409  0.015202  0.029693
# 490            3822   0.634409  0.015202  0.029693
# 448            3822   0.634409  0.015202  0.029693
# 466            3822   0.634409  0.015202  0.029693
# 550             227   0.071051  0.941510  0.132130
# 532             310   0.086069  0.920124  0.157413
# 544             881   0.362889  0.772997  0.493908
# 538             417   0.122554  0.892553  0.215517
# 424            3828   0.557895  0.013656  0.026660
# 418            3833   0.551724  0.012368  0.024194
# 436            3828   0.449153  0.013656  0.026507
# 430            3828   0.473214  0.013656  0.026546
# 562            3849   0.256000  0.008245  0.015976
# 556            3849   0.351648  0.008245  0.016113
# 514             512   0.401597  0.868075  0.549144
# 502             512   0.400261  0.868075  0.547894
# 496             519   0.421462  0.866272  0.567043
# 520             283   0.058764  0.927081  0.110522
# 508             346   0.142707  0.910848  0.246754
# 256           13013   0.039735  0.001841  0.003519
# 202            7949   0.498286  0.390274  0.437715
# 178           11453   0.586232  0.121500  0.201283
# 208           11455   0.588542  0.121347  0.201208
# 190            7952   0.500936  0.390044  0.438589
# 214             899   0.051374  0.931042  0.097375
# 220           11198   0.549611  0.141060  0.224501
# 184            2456   0.290455  0.811613  0.427809
# 196           11200   0.550825  0.140907  0.224408
# 280             637   0.057229  0.951139  0.107962
# 262            1204   0.071290  0.907647  0.132198
# 274            2259   0.278120  0.826724  0.416219
# 268            1208   0.104129  0.907341  0.186817
# 160            9263   0.374219  0.289484  0.326442
# 154            9263   0.383420  0.289484  0.329895
# 172            5645   0.113092  0.567002  0.188571
# 166            6462   0.223199  0.504334  0.309448
# 292            8757   0.054905  0.328296  0.094076
# 286            9011   0.130748  0.308813  0.183714
# 244            7911   0.380662  0.393189  0.386824
# 232            7910   0.367237  0.393265  0.379806
# 226            7911   0.407699  0.393189  0.400312
# 250            3950   0.069943  0.697016  0.127129
# 238            6665   0.147825  0.488763  0.226996
# 376           13586   0.078652  0.000515  0.001023
# 352           12983   0.509607  0.044876  0.082488
# 322           12980   0.511259  0.045097  0.082883
# 358           12980   0.511259  0.045097  0.082883
# 334           12983   0.509607  0.044876  0.082488
# 364             421   0.063584  0.969028  0.119338
# 340           12970   0.479969  0.045832  0.083675
# 370           12972   0.496006  0.045685  0.083665
# 328           12966   0.476082  0.046127  0.084105
# 346           12972   0.497596  0.045685  0.083687
# 400             314   0.128362  0.976900  0.226908
# 382            1919   0.152623  0.858824  0.259186
# 394            2232   0.324294  0.835798  0.467281
# 388            2162   0.209148  0.840948  0.334984
# 304           13088   0.376866  0.037151  0.067635
# 298           13088   0.379414  0.037151  0.067676
# 316           13144   0.301545  0.033032  0.059541
# 310           13144   0.301545  0.033032  0.059541
# 412           13302   0.093239  0.021408  0.034821
# 406           13281   0.232489  0.022953  0.041781
# 676             954   1.000000  0.020534  0.040241
# 622             136   0.884900  0.860370  0.872462
# 592             136   0.884900  0.860370  0.872462
# 628             136   0.884900  0.860370  0.872462
# 604             136   0.884900  0.860370  0.872462
# 634             114   0.670827  0.882957  0.762411
# 610             134   0.882353  0.862423  0.872274
# 640             136   0.883966  0.860370  0.872008
# 598             133   0.882476  0.863450  0.872859
# 616             136   0.883966  0.860370  0.872008
# 700              62   0.582748  0.936345  0.718393
# 682              63   0.583227  0.935318  0.718454
# 694              63   0.637955  0.935318  0.758535
# 688              63   0.618466  0.935318  0.744585
# 574             134   0.815534  0.862423  0.838323
# 568             134   0.815534  0.862423  0.838323
# 586             199   0.759804  0.795688  0.777332
# 580             199   0.759804  0.795688  0.777332
# 712             569   0.442140  0.415811  0.428571
# 706             560   0.405485  0.425051  0.415038
# 664              66   0.889324  0.932238  0.910276
# 652              66   0.879845  0.932238  0.905284
# 646              66   0.889324  0.932238  0.910276
# 670              68   0.443683  0.930185  0.600796
# 658              66   0.657019  0.932238  0.770798
# 112            3062   0.000000  0.000000  0.000000
# 58             2201   0.216549  0.281189  0.244672
# 28             3062   0.000000  0.000000  0.000000
# 64             3062   0.000000  0.000000  0.000000
# 40             2201   0.217699  0.281189  0.245404
# 70              169   0.036473  0.944807  0.070235
# 46             3062   0.000000  0.000000  0.000000
# 76             3062   0.000000  0.000000  0.000000
# 34             3062   0.000000  0.000000  0.000000
# 52             3062   0.000000  0.000000  0.000000
# 136             130   0.045099  0.957544  0.086140
# 118             218   0.061818  0.928805  0.115921
# 130            3062   0.000000  0.000000  0.000000
# 124            2652   0.029138  0.133899  0.047861
# 10             3062   0.000000  0.000000  0.000000
# 4              3062   0.000000  0.000000  0.000000
# 22             1524   0.059756  0.502286  0.106806
# 16             3062   0.000000  0.000000  0.000000
# 148            3062   0.000000  0.000000  0.000000
# 142            3062   0.000000  0.000000  0.000000
# 100            3062   0.000000  0.000000  0.000000
# 88             3062   0.000000  0.000000  0.000000
# 82             3062   0.000000  0.000000  0.000000
# 106            3062   0.000000  0.000000  0.000000
# 94             3062   0.000000  0.000000  0.000000

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[(df['scope'] == 'edges-with-callsite-line-numbers') & (df['package'] == 'package')])
# Out:
#     project framework     algo                             scope  package  \
# 527   axion      Doop    0-CFA  edges-with-callsite-line-numbers  package
# 473   axion      OPAL  0-1-CFA  edges-with-callsite-line-numbers  package
# 443   axion      OPAL    0-CFA  edges-with-callsite-line-numbers  package
# 479   axion      OPAL  1-0-CFA  edges-with-callsite-line-numbers  package
# 455   axion      OPAL  1-1-CFA  edges-with-callsite-line-numbers  package
# 485   axion      OPAL      CHA  edges-with-callsite-line-numbers  package
# 461   axion      OPAL      CTA  edges-with-callsite-line-numbers  package
# 491   axion      OPAL      FTA  edges-with-callsite-line-numbers  package
# 449   axion      OPAL      RTA  edges-with-callsite-line-numbers  package
# 467   axion      OPAL      XTA  edges-with-callsite-line-numbers  package
# 551   axion      Soot      CHA  edges-with-callsite-line-numbers  package
# 533   axion      Soot      RTA  edges-with-callsite-line-numbers  package
# 545   axion      Soot    SPARK  edges-with-callsite-line-numbers  package
# 539   axion      Soot      VTA  edges-with-callsite-line-numbers  package
# 425   axion    SootUp    0-CFA  edges-with-callsite-line-numbers  package
# 419   axion    SootUp    1-CFA  edges-with-callsite-line-numbers  package
# 437   axion    SootUp      CHA  edges-with-callsite-line-numbers  package
# 431   axion    SootUp      RTA  edges-with-callsite-line-numbers  package
# 563   axion      Taie      CHA  edges-with-callsite-line-numbers  package
# 557   axion      Taie      PTA  edges-with-callsite-line-numbers  package
# 515   axion      WALA  0-1-CFA  edges-with-callsite-line-numbers  package
# 503   axion      WALA    0-CFA  edges-with-callsite-line-numbers  package
# 497   axion      WALA    1-CFA  edges-with-callsite-line-numbers  package
# 521   axion      WALA      CHA  edges-with-callsite-line-numbers  package
# 509   axion      WALA      RTA  edges-with-callsite-line-numbers  package
# 257   batik      Doop    0-CFA  edges-with-callsite-line-numbers  package
# 203   batik      OPAL  0-1-CFA  edges-with-callsite-line-numbers  package
# 179   batik      OPAL    0-CFA  edges-with-callsite-line-numbers  package
# 209   batik      OPAL  1-0-CFA  edges-with-callsite-line-numbers  package
# 191   batik      OPAL  1-1-CFA  edges-with-callsite-line-numbers  package
# 215   batik      OPAL      CHA  edges-with-callsite-line-numbers  package
# 221   batik      OPAL      FTA  edges-with-callsite-line-numbers  package
# 185   batik      OPAL      RTA  edges-with-callsite-line-numbers  package
# 197   batik      OPAL      XTA  edges-with-callsite-line-numbers  package
# 281   batik      Soot      CHA  edges-with-callsite-line-numbers  package
# 263   batik      Soot      RTA  edges-with-callsite-line-numbers  package
# 275   batik      Soot    SPARK  edges-with-callsite-line-numbers  package
# 269   batik      Soot      VTA  edges-with-callsite-line-numbers  package
# 161   batik    SootUp    0-CFA  edges-with-callsite-line-numbers  package
# 155   batik    SootUp    1-CFA  edges-with-callsite-line-numbers  package
# 173   batik    SootUp      CHA  edges-with-callsite-line-numbers  package
# 167   batik    SootUp      RTA  edges-with-callsite-line-numbers  package
# 293   batik      Taie      CHA  edges-with-callsite-line-numbers  package
# 287   batik      Taie      PTA  edges-with-callsite-line-numbers  package
# 245   batik      WALA  0-1-CFA  edges-with-callsite-line-numbers  package
# 233   batik      WALA    0-CFA  edges-with-callsite-line-numbers  package
# 227   batik      WALA    1-CFA  edges-with-callsite-line-numbers  package
# 251   batik      WALA      CHA  edges-with-callsite-line-numbers  package
# 239   batik      WALA      RTA  edges-with-callsite-line-numbers  package
# 377  hsqldb      Doop    0-CFA  edges-with-callsite-line-numbers  package
# 353  hsqldb      OPAL  0-1-CFA  edges-with-callsite-line-numbers  package
# 323  hsqldb      OPAL    0-CFA  edges-with-callsite-line-numbers  package
# 359  hsqldb      OPAL  1-0-CFA  edges-with-callsite-line-numbers  package
# 335  hsqldb      OPAL  1-1-CFA  edges-with-callsite-line-numbers  package
# 365  hsqldb      OPAL      CHA  edges-with-callsite-line-numbers  package
# 341  hsqldb      OPAL      CTA  edges-with-callsite-line-numbers  package
# 371  hsqldb      OPAL      FTA  edges-with-callsite-line-numbers  package
# 329  hsqldb      OPAL      RTA  edges-with-callsite-line-numbers  package
# 347  hsqldb      OPAL      XTA  edges-with-callsite-line-numbers  package
# 401  hsqldb      Soot      CHA  edges-with-callsite-line-numbers  package
# 383  hsqldb      Soot      RTA  edges-with-callsite-line-numbers  package
# 395  hsqldb      Soot    SPARK  edges-with-callsite-line-numbers  package
# 389  hsqldb      Soot      VTA  edges-with-callsite-line-numbers  package
# 305  hsqldb    SootUp    0-CFA  edges-with-callsite-line-numbers  package
# 299  hsqldb    SootUp    1-CFA  edges-with-callsite-line-numbers  package
# 317  hsqldb    SootUp      CHA  edges-with-callsite-line-numbers  package
# 311  hsqldb    SootUp      RTA  edges-with-callsite-line-numbers  package
# 413  hsqldb      Taie      CHA  edges-with-callsite-line-numbers  package
# 407  hsqldb      Taie      PTA  edges-with-callsite-line-numbers  package
# 677   jasml      Doop    0-CFA  edges-with-callsite-line-numbers  package
# 623   jasml      OPAL  0-1-CFA  edges-with-callsite-line-numbers  package
# 593   jasml      OPAL    0-CFA  edges-with-callsite-line-numbers  package
# 629   jasml      OPAL  1-0-CFA  edges-with-callsite-line-numbers  package
# 605   jasml      OPAL  1-1-CFA  edges-with-callsite-line-numbers  package
# 635   jasml      OPAL      CHA  edges-with-callsite-line-numbers  package
# 611   jasml      OPAL      CTA  edges-with-callsite-line-numbers  package
# 641   jasml      OPAL      FTA  edges-with-callsite-line-numbers  package
# 599   jasml      OPAL      RTA  edges-with-callsite-line-numbers  package
# 617   jasml      OPAL      XTA  edges-with-callsite-line-numbers  package
# 701   jasml      Soot      CHA  edges-with-callsite-line-numbers  package
# 683   jasml      Soot      RTA  edges-with-callsite-line-numbers  package
# 695   jasml      Soot    SPARK  edges-with-callsite-line-numbers  package
# 689   jasml      Soot      VTA  edges-with-callsite-line-numbers  package
# 575   jasml    SootUp    0-CFA  edges-with-callsite-line-numbers  package
# 569   jasml    SootUp    1-CFA  edges-with-callsite-line-numbers  package
# 587   jasml    SootUp      CHA  edges-with-callsite-line-numbers  package
# 581   jasml    SootUp      RTA  edges-with-callsite-line-numbers  package
# 713   jasml      Taie      CHA  edges-with-callsite-line-numbers  package
# 707   jasml      Taie      PTA  edges-with-callsite-line-numbers  package
# 665   jasml      WALA  0-1-CFA  edges-with-callsite-line-numbers  package
# 653   jasml      WALA    0-CFA  edges-with-callsite-line-numbers  package
# 647   jasml      WALA    1-CFA  edges-with-callsite-line-numbers  package
# 671   jasml      WALA      CHA  edges-with-callsite-line-numbers  package
# 659   jasml      WALA      RTA  edges-with-callsite-line-numbers  package
# 113  xerces      Doop    0-CFA  edges-with-callsite-line-numbers  package
# 59   xerces      OPAL  0-1-CFA  edges-with-callsite-line-numbers  package
# 29   xerces      OPAL    0-CFA  edges-with-callsite-line-numbers  package
# 65   xerces      OPAL  1-0-CFA  edges-with-callsite-line-numbers  package
# 41   xerces      OPAL  1-1-CFA  edges-with-callsite-line-numbers  package
# 71   xerces      OPAL      CHA  edges-with-callsite-line-numbers  package
# 47   xerces      OPAL      CTA  edges-with-callsite-line-numbers  package
# 77   xerces      OPAL      FTA  edges-with-callsite-line-numbers  package
# 35   xerces      OPAL      RTA  edges-with-callsite-line-numbers  package
# 53   xerces      OPAL      XTA  edges-with-callsite-line-numbers  package
# 137  xerces      Soot      CHA  edges-with-callsite-line-numbers  package
# 119  xerces      Soot      RTA  edges-with-callsite-line-numbers  package
# 131  xerces      Soot    SPARK  edges-with-callsite-line-numbers  package
# 125  xerces      Soot      VTA  edges-with-callsite-line-numbers  package
# 11   xerces    SootUp    0-CFA  edges-with-callsite-line-numbers  package
# 5    xerces    SootUp    1-CFA  edges-with-callsite-line-numbers  package
# 23   xerces    SootUp      CHA  edges-with-callsite-line-numbers  package
# 17   xerces    SootUp      RTA  edges-with-callsite-line-numbers  package
# 149  xerces      Taie      CHA  edges-with-callsite-line-numbers  package
# 143  xerces      Taie      PTA  edges-with-callsite-line-numbers  package
# 101  xerces      WALA  0-1-CFA  edges-with-callsite-line-numbers  package
# 89   xerces      WALA    0-CFA  edges-with-callsite-line-numbers  package
# 83   xerces      WALA    1-CFA  edges-with-callsite-line-numbers  package
# 107  xerces      WALA      CHA  edges-with-callsite-line-numbers  package
# 95   xerces      WALA      RTA  edges-with-callsite-line-numbers  package
#
#      true_positive  false_positive  false_negative  precision    recall  \
# 527             14             210            4964   0.062500  0.002812
# 473             82              52            4896   0.611940  0.016472
# 443             82              52            4896   0.611940  0.016472
# 479             82              52            4896   0.611940  0.016472
# 455             82              52            4896   0.611940  0.016472
# 485           4200           72938             778   0.054448  0.843712
# 461             85              52            4893   0.620438  0.017075
# 491             85              52            4893   0.620438  0.017075
# 449             85              52            4893   0.620438  0.017075
# 467             85              52            4893   0.620438  0.017075
# 551           4699           59451             279   0.073250  0.943953
# 533           4570           47412             408   0.087915  0.918039
# 545           3964            6608            1014   0.374953  0.796304
# 539           4457           31505             521   0.123936  0.895339
# 425             74              69            4904   0.517483  0.014865
# 419             62              54            4916   0.534483  0.012455
# 437             74              95            4904   0.437870  0.014865
# 431             74              89            4904   0.453988  0.014865
# 563             51             122            4927   0.294798  0.010245
# 557             51              87            4927   0.369565  0.010245
# 515           4343            7178             635   0.376964  0.872439
# 503           4343            7206             635   0.376050  0.872439
# 497           4325            6715             653   0.391757  0.868823
# 521           4621           72739             357   0.059734  0.928284
# 509           4512           27372             466   0.141513  0.906388
# 257             30             682           13023   0.042135  0.002298
# 203           5099            5140            7954   0.497998  0.390638
# 179           1587            1124           11466   0.585393  0.121581
# 209           1585            1112           11468   0.587690  0.121428
# 191           5096            5083            7957   0.500639  0.390408
# 215          12149          233207             904   0.049516  0.930744
# 221           1842            4311           11211   0.299366  0.141117
# 185          10584           28864            2469   0.268303  0.810848
# 197           1840            4302           11213   0.299577  0.140964
# 281          12414          219659             639   0.053492  0.951046
# 263          11847          164647            1206   0.067124  0.907607
# 275          10784           28141            2269   0.277046  0.826170
# 269          11843          108467            1210   0.098437  0.907301
# 161           3777            6370            9276   0.372228  0.289359
# 155           3777            6109            9276   0.382055  0.289359
# 173           7395           59189            5658   0.111063  0.566536
# 167           6578           22886            6475   0.223255  0.503945
# 293           4279           75332            8774   0.053749  0.327817
# 287           4030           27076            9023   0.129557  0.308741
# 245           5115           10522            7938   0.327109  0.391864
# 233           5116           11028            7937   0.316898  0.391941
# 227           5115            7518            7938   0.404892  0.391864
# 251           9083          130713            3970   0.064973  0.695855
# 239           6360           40608            6693   0.135411  0.487244
# 377              7              94           13587   0.069307  0.000515
# 353            610             587           12984   0.509607  0.044873
# 323            613             586           12981   0.511259  0.045093
# 359            613             586           12981   0.511259  0.045093
# 335            610             587           12984   0.509607  0.044873
# 365          13172          330685             422   0.038307  0.968957
# 341            623             675           12971   0.479969  0.045829
# 371            621             631           12973   0.496006  0.045682
# 329            627             690           12967   0.476082  0.046123
# 347            621             627           12973   0.497596  0.045682
# 401          13280           93233             314   0.124680  0.976902
# 383          11675           66634            1919   0.149089  0.858835
# 395          11362           23817            2232   0.322977  0.835810
# 389          11432           44014            2162   0.206183  0.840959
# 305            505             838           13089   0.376024  0.037149
# 299            505             826           13089   0.379414  0.037149
# 317            449            1040           13145   0.301545  0.033029
# 311            449            1040           13145   0.301545  0.033029
# 413            291            2830           13303   0.093239  0.021407
# 407            312            1033           13282   0.231970  0.022951
# 677             12               8            2248   0.600000  0.005310
# 623           1995             536             265   0.788226  0.882743
# 593           1995             536             265   0.788226  0.882743
# 629           1995             536             265   0.788226  0.882743
# 605           1995             536             265   0.788226  0.882743
# 635           2083            3013             177   0.408752  0.921681
# 611           1984             543             276   0.785121  0.877876
# 641           1995             541             265   0.786672  0.882743
# 599           1998             543             262   0.786305  0.884071
# 617           1995             541             265   0.786672  0.882743
# 701           2081            1288             179   0.617691  0.920796
# 683           2080            1286             180   0.617944  0.920354
# 695           2080            1121             180   0.649797  0.920354
# 689           2080            1177             180   0.638625  0.920354
# 575           1506            1124             754   0.572624  0.666372
# 569           1506            1124             754   0.572624  0.666372
# 587           1429            1750             831   0.449512  0.632301
# 581           1429            1750             831   0.449512  0.632301
# 713            815            1175            1445   0.409548  0.360619
# 707            852            1769            1408   0.325067  0.376991
# 665           2065             556             195   0.787867  0.913717
# 653           2065             567             195   0.784574  0.913717
# 647           2065             556             195   0.787867  0.913717
# 671           1643            1688             617   0.493245  0.726991
# 659           2065             934             195   0.688563  0.913717
# 113              0               0            3063   0.000000  0.000000
# 59             860            3116            2203   0.216298  0.280770
# 29               0               0            3063   0.000000  0.000000
# 65               0               0            3063   0.000000  0.000000
# 41             860            3095            2203   0.217446  0.280770
# 71            2892           76426             171   0.036461  0.944172
# 47               0               0            3063   0.000000  0.000000
# 77               0               0            3063   0.000000  0.000000
# 35               0               0            3063   0.000000  0.000000
# 53               0               0            3063   0.000000  0.000000
# 137           2932           64801             131   0.043288  0.957231
# 119           2844           45288             219   0.059088  0.928501
# 131              0               0            3063   0.000000  0.000000
# 125            410           14572            2653   0.027366  0.133856
# 11               0               0            3063   0.000000  0.000000
# 5                0               0            3063   0.000000  0.000000
# 23            1537           24201            1526   0.059717  0.501796
# 17               0               0            3063   0.000000  0.000000
# 149              0               0            3063   0.000000  0.000000
# 143              0               0            3063   0.000000  0.000000
# 101              0               0            3063   0.000000  0.000000
# 89               0               0            3063   0.000000  0.000000
# 83               0               0            3063   0.000000  0.000000
# 107              0              82            3063   0.000000  0.000000
# 95               0               0            3063   0.000000  0.000000
#
#      f1-score
# 527  0.005383
# 473  0.032081
# 443  0.032081
# 479  0.032081
# 455  0.032081
# 485  0.102294
# 461  0.033236
# 491  0.033236
# 449  0.033236
# 467  0.033236
# 551  0.135951
# 533  0.160463
# 545  0.509839
# 539  0.217733
# 425  0.028901
# 419  0.024342
# 437  0.028755
# 431  0.028788
# 563  0.019802
# 557  0.019937
# 515  0.526456
# 503  0.525564
# 497  0.540017
# 521  0.112245
# 509  0.244805
# 257  0.004359
# 203  0.437833
# 179  0.201345
# 209  0.201270
# 191  0.438705
# 215  0.094029
# 221  0.191815
# 185  0.403192
# 197  0.191717
# 281  0.101287
# 263  0.125003
# 275  0.414945
# 269  0.177605
# 161  0.325603
# 155  0.329308
# 173  0.185718
# 167  0.309429
# 293  0.092355
# 287  0.182522
# 245  0.356570
# 233  0.350447
# 227  0.398271
# 251  0.118849
# 239  0.211926
# 377  0.001022
# 353  0.082483
# 323  0.082877
# 359  0.082877
# 335  0.082483
# 365  0.073700
# 341  0.083669
# 371  0.083659
# 329  0.084099
# 347  0.083681
# 401  0.221136
# 383  0.254072
# 395  0.465914
# 389  0.331170
# 305  0.067617
# 299  0.067672
# 317  0.059537
# 311  0.059537
# 413  0.034819
# 407  0.041770
# 677  0.010526
# 623  0.832812
# 593  0.832812
# 629  0.832812
# 605  0.832812
# 635  0.566340
# 611  0.828912
# 641  0.831943
# 599  0.832327
# 617  0.831943
# 701  0.739385
# 683  0.739424
# 695  0.761765
# 689  0.754033
# 575  0.615951
# 569  0.615951
# 587  0.525464
# 581  0.525464
# 713  0.383529
# 707  0.349109
# 665  0.846138
# 653  0.844235
# 647  0.846138
# 671  0.587730
# 659  0.785320
# 113  0.000000
# 59   0.244353
# 29   0.000000
# 65   0.000000
# 41   0.245084
# 71   0.070210
# 47   0.000000
# 77   0.000000
# 35   0.000000
# 53   0.000000
# 137  0.082830
# 119  0.111105
# 131  0.000000
# 125  0.045442
# 11   0.000000
# 5    0.000000
# 23   0.106732
# 17   0.000000
# 149  0.000000
# 143  0.000000
# 101  0.000000
# 89   0.000000
# 83   0.000000
# 107  0.000000
# 95   0.000000

# %%
df = data.reset_index()
display(df[(df['project'] == 'jasml') & (df['framework'] == 'WALA') & (df['scope'] == 'edge') & (df['package'] == 'package') & (df['metric'] == 'Static CG Size')])
display(df[(df['project'] == 'jasml') & (df['framework'] == 'WALA') & (df['scope'] == 'edge') & (df['package'] == 'package') & (df['metric'] == 'Recall')])

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method']:
    for package in ['package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["project"] == "axion") & (df["framework"] == "WALA")],
                             #row='project',
                             #row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.4,
                             aspect=1.6,
                             gridspec_kws={"wspace":0.5, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           #hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6,
                           dodge=True)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")

        grid.set_yticklabels(["  CHA", "  RTA", "0-CFA"], rotation=0, verticalalignment="center", fontsize=18)
        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        grid.set(xlabel=None)
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        #grid.fig.tight_layout()
        #pyplot.tight_layout()
        #grid.add_legend(ncols=2)
        #sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.127), ncols=1)
        pyplot.savefig('/out/axion-wala-method-package.pdf', dpi=300, bbox_inches="tight")
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['edge']:
    for package in ['all']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["algo"] == "CHA") & (df["framework"] != "Soot") & (df["framework"] != "Doop")],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1,
                             aspect=2.6,
                             gridspec_kws={"wspace":0.25, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA'],
                           #order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: "0%" if(x == 0) else str(round(x, 1)) + "%"))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}M'.format(int(x/1000000))))

            bar_cnt = 1
            special = [5,6,11,12,17,18,23,24]
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                
                for container in ax.containers:
                    
                    for bar in container:
                        if bar_cnt in special:
                            ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(-33, -12.5), color="white", textcoords="offset points")
                        else:
                            ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")
                        bar_cnt = bar_cnt + 1

        grid.despine(left=True, bottom=True)
        grid.set(xlabel=None)
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        grid.fig.tight_layout()
        pyplot.tight_layout()
        grid.add_legend(ncols=3)
        sns.move_legend(grid, "lower left", bbox_to_anchor=(0.23,0.32), ncols=1)
        pyplot.savefig('/out/cha-edge-all.pdf', dpi=300)
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['edge']:
    for package in ['all']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["algo"] == "0-CFA")],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.5,
                             aspect=1.7,
                             gridspec_kws={"wspace":0.25, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Doop'],
                           #order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))

            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        trunc = (human_format(bar.get_width()) == "605.3K")
                        ax.annotate(human_format(bar.get_width()), size=14, color = "white" if trunc else "black", xy=(bar.get_width(),bar.xy[1]), xytext=(-46 if trunc else 1.3, -12.5), textcoords="offset points")

        grid.despine(left=True, bottom=True)
        grid.set(xlabel=None)
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        grid.fig.tight_layout()
        pyplot.tight_layout()
        grid.add_legend(ncols=3)
        sns.move_legend(grid, "lower right", bbox_to_anchor=(0.91,0.425), ncols=1)
        pyplot.savefig('/out/0cfa-only.pdf', dpi=300)
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method']:
    for package in ['package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["project"] == "xerces") & (df["metric"] != "Precision")],
                             #row='project',
                             #row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=5,
                             aspect=0.7,
                             gridspec_kws={"wspace":0.5, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6,
                           dodge=True)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            #axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")

        grid.set_yticklabels(["  CHA", "  RTA", "0-CFA"], rotation=90, verticalalignment="center", fontsize=18)
        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        grid.set(xlabel=None)
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        #grid.fig.tight_layout()
        #pyplot.tight_layout()
        grid.add_legend(ncols=2)
        sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.127), ncols=1)
        pyplot.savefig('/out/xerces-filtered.pdf', dpi=300, bbox_inches="tight")
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method', 'edge']:
    for package in ['all', 'package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package)],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.5,
                             aspect=1.7)
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind')
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=6, xy=(bar.get_width(),bar.xy[1]), xytext=(1, -4.5), textcoords="offset points")
                    #labels = ['' if v == nan_num else human_format(v) for v in container.datavalues]
                    #ax.bar_label(container,labels=labels,size=7)

        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
                sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.325))
        grid.fig.tight_layout()
        pyplot.tight_layout()
        pyplot.savefig("/out/" + scope+'-'+package+'.pdf', dpi=300)
        pyplot.show()
