# %%
import os
import sys

module_path = os.path.abspath(os.path.join('.', 'src')) 
sys.path.append(module_path)

from parse import read_results
from compute import *

data = read_results(os.path.abspath('target'))
# data = columns_to_rows(data)

data

# df = data.sort_values(by=['project', 'framework', 'algo', 'scope', 'package'])
# df = data.sort_values(by=['project', 'f1-score'])
# df.to_csv('precision-recall.csv', index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[(df['scope'] == 'edges-with-callsite-line-numbers') & (df['package'] == 'package')])
# Out:
#             project framework     algo                             scope  \
# 338    axion-1.0-M2      Taie      CHA  edges-with-callsite-line-numbers
# 332    axion-1.0-M2      Taie      PTA  edges-with-callsite-line-numbers
# 200    axion-1.0-M2    SootUp      RTA  edges-with-callsite-line-numbers
# 212    axion-1.0-M2      OPAL    0-CFA  edges-with-callsite-line-numbers
# 224    axion-1.0-M2      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 242    axion-1.0-M2      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 248    axion-1.0-M2      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 218    axion-1.0-M2      OPAL      RTA  edges-with-callsite-line-numbers
# 230    axion-1.0-M2      OPAL      CTA  edges-with-callsite-line-numbers
# 236    axion-1.0-M2      OPAL      XTA  edges-with-callsite-line-numbers
# 260    axion-1.0-M2      OPAL      FTA  edges-with-callsite-line-numbers
# 206    axion-1.0-M2    SootUp      CHA  edges-with-callsite-line-numbers
# 254    axion-1.0-M2      OPAL      CHA  edges-with-callsite-line-numbers
# 290    axion-1.0-M2      WALA      CHA  edges-with-callsite-line-numbers
# 326    axion-1.0-M2      Soot      CHA  edges-with-callsite-line-numbers
# 308    axion-1.0-M2      Soot      RTA  edges-with-callsite-line-numbers
# 314    axion-1.0-M2      Soot      VTA  edges-with-callsite-line-numbers
# 278    axion-1.0-M2      WALA      RTA  edges-with-callsite-line-numbers
# 302    axion-1.0-M2   ValueCG     fast  edges-with-callsite-line-numbers
# 296    axion-1.0-M2   ValueCG  precise  edges-with-callsite-line-numbers
# 320    axion-1.0-M2      Soot    SPARK  edges-with-callsite-line-numbers
# 272    axion-1.0-M2      WALA    0-CFA  edges-with-callsite-line-numbers
# 284    axion-1.0-M2      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 266    axion-1.0-M2      WALA    1-CFA  edges-with-callsite-line-numbers
# 638    hsqldb-2.0.0      Taie      CHA  edges-with-callsite-line-numbers
# 632    hsqldb-2.0.0      Taie      PTA  edges-with-callsite-line-numbers
# 494    hsqldb-2.0.0    SootUp      RTA  edges-with-callsite-line-numbers
# 572    hsqldb-2.0.0      WALA      RTA  edges-with-callsite-line-numbers
# 548    hsqldb-2.0.0      OPAL      CHA  edges-with-callsite-line-numbers
# 518    hsqldb-2.0.0      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 536    hsqldb-2.0.0      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 506    hsqldb-2.0.0      OPAL    0-CFA  edges-with-callsite-line-numbers
# 542    hsqldb-2.0.0      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 554    hsqldb-2.0.0      OPAL      FTA  edges-with-callsite-line-numbers
# 530    hsqldb-2.0.0      OPAL      XTA  edges-with-callsite-line-numbers
# 524    hsqldb-2.0.0      OPAL      CTA  edges-with-callsite-line-numbers
# 512    hsqldb-2.0.0      OPAL      RTA  edges-with-callsite-line-numbers
# 578    hsqldb-2.0.0      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 560    hsqldb-2.0.0      WALA    1-CFA  edges-with-callsite-line-numbers
# 566    hsqldb-2.0.0      WALA    0-CFA  edges-with-callsite-line-numbers
# 590    hsqldb-2.0.0      Doop    0-CFA  edges-with-callsite-line-numbers
# 500    hsqldb-2.0.0    SootUp      CHA  edges-with-callsite-line-numbers
# 626    hsqldb-2.0.0      Soot      CHA  edges-with-callsite-line-numbers
# 608    hsqldb-2.0.0      Soot      RTA  edges-with-callsite-line-numbers
# 584    hsqldb-2.0.0      WALA      CHA  edges-with-callsite-line-numbers
# 614    hsqldb-2.0.0      Soot      VTA  edges-with-callsite-line-numbers
# 620    hsqldb-2.0.0      Soot    SPARK  edges-with-callsite-line-numbers
# 602    hsqldb-2.0.0   ValueCG     fast  edges-with-callsite-line-numbers
# 596    hsqldb-2.0.0   ValueCG  precise  edges-with-callsite-line-numbers
# 149    hsqldb-2.7.4      Taie      CHA  edges-with-callsite-line-numbers
# 143    hsqldb-2.7.4      Taie      PTA  edges-with-callsite-line-numbers
# 5      hsqldb-2.7.4    SootUp      RTA  edges-with-callsite-line-numbers
# 83     hsqldb-2.7.4      WALA      RTA  edges-with-callsite-line-numbers
# 29     hsqldb-2.7.4      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 47     hsqldb-2.7.4      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 17     hsqldb-2.7.4      OPAL    0-CFA  edges-with-callsite-line-numbers
# 53     hsqldb-2.7.4      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 35     hsqldb-2.7.4      OPAL      CTA  edges-with-callsite-line-numbers
# 23     hsqldb-2.7.4      OPAL      RTA  edges-with-callsite-line-numbers
# 65     hsqldb-2.7.4      OPAL      FTA  edges-with-callsite-line-numbers
# 41     hsqldb-2.7.4      OPAL      XTA  edges-with-callsite-line-numbers
# 89     hsqldb-2.7.4      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 77     hsqldb-2.7.4      WALA    0-CFA  edges-with-callsite-line-numbers
# 71     hsqldb-2.7.4      WALA    1-CFA  edges-with-callsite-line-numbers
# 11     hsqldb-2.7.4    SootUp      CHA  edges-with-callsite-line-numbers
# 137    hsqldb-2.7.4      Soot      CHA  edges-with-callsite-line-numbers
# 119    hsqldb-2.7.4      Soot      RTA  edges-with-callsite-line-numbers
# 59     hsqldb-2.7.4      OPAL      CHA  edges-with-callsite-line-numbers
# 125    hsqldb-2.7.4      Soot      VTA  edges-with-callsite-line-numbers
# 95     hsqldb-2.7.4      WALA      CHA  edges-with-callsite-line-numbers
# 131    hsqldb-2.7.4      Soot    SPARK  edges-with-callsite-line-numbers
# 101    hsqldb-2.7.4      Doop    0-CFA  edges-with-callsite-line-numbers
# 107    hsqldb-2.7.4   ValueCG  precise  edges-with-callsite-line-numbers
# 113    hsqldb-2.7.4   ValueCG     fast  edges-with-callsite-line-numbers
# 1082     jasml-0.10      Taie      PTA  edges-with-callsite-line-numbers
# 1088     jasml-0.10      Taie      CHA  edges-with-callsite-line-numbers
# 950      jasml-0.10    SootUp      CHA  edges-with-callsite-line-numbers
# 944      jasml-0.10    SootUp      RTA  edges-with-callsite-line-numbers
# 998      jasml-0.10      OPAL      CHA  edges-with-callsite-line-numbers
# 1034     jasml-0.10      WALA      CHA  edges-with-callsite-line-numbers
# 1046     jasml-0.10   ValueCG  precise  edges-with-callsite-line-numbers
# 1076     jasml-0.10      Soot      CHA  edges-with-callsite-line-numbers
# 1058     jasml-0.10      Soot      RTA  edges-with-callsite-line-numbers
# 1064     jasml-0.10      Soot      VTA  edges-with-callsite-line-numbers
# 1070     jasml-0.10      Soot    SPARK  edges-with-callsite-line-numbers
# 1040     jasml-0.10      Doop    0-CFA  edges-with-callsite-line-numbers
# 1022     jasml-0.10      WALA      RTA  edges-with-callsite-line-numbers
# 1052     jasml-0.10   ValueCG     fast  edges-with-callsite-line-numbers
# 1016     jasml-0.10      WALA    0-CFA  edges-with-callsite-line-numbers
# 1010     jasml-0.10      WALA    1-CFA  edges-with-callsite-line-numbers
# 1028     jasml-0.10      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 974      jasml-0.10      OPAL      CTA  edges-with-callsite-line-numbers
# 980      jasml-0.10      OPAL      XTA  edges-with-callsite-line-numbers
# 1004     jasml-0.10      OPAL      FTA  edges-with-callsite-line-numbers
# 962      jasml-0.10      OPAL      RTA  edges-with-callsite-line-numbers
# 956      jasml-0.10      OPAL    0-CFA  edges-with-callsite-line-numbers
# 968      jasml-0.10      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 986      jasml-0.10      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 992      jasml-0.10      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 488      javacc-5.0      Taie      CHA  edges-with-callsite-line-numbers
# 482      javacc-5.0      Taie      PTA  edges-with-callsite-line-numbers
# 350      javacc-5.0    SootUp      CHA  edges-with-callsite-line-numbers
# 398      javacc-5.0      OPAL      CHA  edges-with-callsite-line-numbers
# 434      javacc-5.0      WALA      CHA  edges-with-callsite-line-numbers
# 476      javacc-5.0      Soot      CHA  edges-with-callsite-line-numbers
# 458      javacc-5.0      Soot      RTA  edges-with-callsite-line-numbers
# 344      javacc-5.0    SootUp      RTA  edges-with-callsite-line-numbers
# 464      javacc-5.0      Soot      VTA  edges-with-callsite-line-numbers
# 422      javacc-5.0      WALA      RTA  edges-with-callsite-line-numbers
# 470      javacc-5.0      Soot    SPARK  edges-with-callsite-line-numbers
# 446      javacc-5.0   ValueCG  precise  edges-with-callsite-line-numbers
# 452      javacc-5.0   ValueCG     fast  edges-with-callsite-line-numbers
# 440      javacc-5.0      Doop    0-CFA  edges-with-callsite-line-numbers
# 368      javacc-5.0      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 386      javacc-5.0      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 356      javacc-5.0      OPAL    0-CFA  edges-with-callsite-line-numbers
# 392      javacc-5.0      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 362      javacc-5.0      OPAL      RTA  edges-with-callsite-line-numbers
# 374      javacc-5.0      OPAL      CTA  edges-with-callsite-line-numbers
# 404      javacc-5.0      OPAL      FTA  edges-with-callsite-line-numbers
# 380      javacc-5.0      OPAL      XTA  edges-with-callsite-line-numbers
# 416      javacc-5.0      WALA    0-CFA  edges-with-callsite-line-numbers
# 428      javacc-5.0      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 410      javacc-5.0      WALA    1-CFA  edges-with-callsite-line-numbers
# 938    javacc-8.1.0      Taie      CHA  edges-with-callsite-line-numbers
# 932    javacc-8.1.0      Taie      PTA  edges-with-callsite-line-numbers
# 800    javacc-8.1.0    SootUp      CHA  edges-with-callsite-line-numbers
# 848    javacc-8.1.0      OPAL      CHA  edges-with-callsite-line-numbers
# 926    javacc-8.1.0      Soot      CHA  edges-with-callsite-line-numbers
# 884    javacc-8.1.0      WALA      CHA  edges-with-callsite-line-numbers
# 908    javacc-8.1.0      Soot      RTA  edges-with-callsite-line-numbers
# 872    javacc-8.1.0      WALA      RTA  edges-with-callsite-line-numbers
# 914    javacc-8.1.0      Soot      VTA  edges-with-callsite-line-numbers
# 920    javacc-8.1.0      Soot    SPARK  edges-with-callsite-line-numbers
# 794    javacc-8.1.0    SootUp      RTA  edges-with-callsite-line-numbers
# 890    javacc-8.1.0      Doop    0-CFA  edges-with-callsite-line-numbers
# 836    javacc-8.1.0      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 818    javacc-8.1.0      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 806    javacc-8.1.0      OPAL    0-CFA  edges-with-callsite-line-numbers
# 842    javacc-8.1.0      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 812    javacc-8.1.0      OPAL      RTA  edges-with-callsite-line-numbers
# 824    javacc-8.1.0      OPAL      CTA  edges-with-callsite-line-numbers
# 830    javacc-8.1.0      OPAL      XTA  edges-with-callsite-line-numbers
# 854    javacc-8.1.0      OPAL      FTA  edges-with-callsite-line-numbers
# 866    javacc-8.1.0      WALA    0-CFA  edges-with-callsite-line-numbers
# 878    javacc-8.1.0      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 860    javacc-8.1.0      WALA    1-CFA  edges-with-callsite-line-numbers
# 902    javacc-8.1.0   ValueCG     fast  edges-with-callsite-line-numbers
# 896    javacc-8.1.0   ValueCG  precise  edges-with-callsite-line-numbers
# 1100   proguard-4.9    SootUp      CHA  edges-with-callsite-line-numbers
# 1232   proguard-4.9      Taie      CHA  edges-with-callsite-line-numbers
# 1184   proguard-4.9      WALA      CHA  edges-with-callsite-line-numbers
# 1226   proguard-4.9      Taie      PTA  edges-with-callsite-line-numbers
# 1220   proguard-4.9      Soot      CHA  edges-with-callsite-line-numbers
# 1202   proguard-4.9      Soot      RTA  edges-with-callsite-line-numbers
# 1172   proguard-4.9      WALA      RTA  edges-with-callsite-line-numbers
# 1148   proguard-4.9      OPAL      CHA  edges-with-callsite-line-numbers
# 1208   proguard-4.9      Soot      VTA  edges-with-callsite-line-numbers
# 1094   proguard-4.9    SootUp      RTA  edges-with-callsite-line-numbers
# 1214   proguard-4.9      Soot    SPARK  edges-with-callsite-line-numbers
# 1112   proguard-4.9      OPAL      RTA  edges-with-callsite-line-numbers
# 1196   proguard-4.9   ValueCG     fast  edges-with-callsite-line-numbers
# 1124   proguard-4.9      OPAL      CTA  edges-with-callsite-line-numbers
# 1166   proguard-4.9      WALA    0-CFA  edges-with-callsite-line-numbers
# 1178   proguard-4.9      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 1160   proguard-4.9      WALA    1-CFA  edges-with-callsite-line-numbers
# 1190   proguard-4.9   ValueCG  precise  edges-with-callsite-line-numbers
# 1130   proguard-4.9      OPAL      XTA  edges-with-callsite-line-numbers
# 1154   proguard-4.9      OPAL      FTA  edges-with-callsite-line-numbers
# 1106   proguard-4.9      OPAL    0-CFA  edges-with-callsite-line-numbers
# 1136   proguard-4.9      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 1142   proguard-4.9      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 1118   proguard-4.9      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 644   xerces-2.10.0    SootUp      RTA  edges-with-callsite-line-numbers
# 656   xerces-2.10.0      OPAL    0-CFA  edges-with-callsite-line-numbers
# 662   xerces-2.10.0      OPAL      RTA  edges-with-callsite-line-numbers
# 674   xerces-2.10.0      OPAL      CTA  edges-with-callsite-line-numbers
# 680   xerces-2.10.0      OPAL      XTA  edges-with-callsite-line-numbers
# 692   xerces-2.10.0      OPAL  1-0-CFA  edges-with-callsite-line-numbers
# 704   xerces-2.10.0      OPAL      FTA  edges-with-callsite-line-numbers
# 710   xerces-2.10.0      WALA    1-CFA  edges-with-callsite-line-numbers
# 716   xerces-2.10.0      WALA    0-CFA  edges-with-callsite-line-numbers
# 722   xerces-2.10.0      WALA      RTA  edges-with-callsite-line-numbers
# 728   xerces-2.10.0      WALA  0-1-CFA  edges-with-callsite-line-numbers
# 734   xerces-2.10.0      WALA      CHA  edges-with-callsite-line-numbers
# 740   xerces-2.10.0      Doop    0-CFA  edges-with-callsite-line-numbers
# 770   xerces-2.10.0      Soot    SPARK  edges-with-callsite-line-numbers
# 782   xerces-2.10.0      Taie      PTA  edges-with-callsite-line-numbers
# 788   xerces-2.10.0      Taie      CHA  edges-with-callsite-line-numbers
# 650   xerces-2.10.0    SootUp      CHA  edges-with-callsite-line-numbers
# 776   xerces-2.10.0      Soot      CHA  edges-with-callsite-line-numbers
# 698   xerces-2.10.0      OPAL      CHA  edges-with-callsite-line-numbers
# 758   xerces-2.10.0      Soot      RTA  edges-with-callsite-line-numbers
# 764   xerces-2.10.0      Soot      VTA  edges-with-callsite-line-numbers
# 746   xerces-2.10.0   ValueCG  precise  edges-with-callsite-line-numbers
# 752   xerces-2.10.0   ValueCG     fast  edges-with-callsite-line-numbers
# 686   xerces-2.10.0      OPAL  0-1-CFA  edges-with-callsite-line-numbers
# 668   xerces-2.10.0      OPAL  1-1-CFA  edges-with-callsite-line-numbers
# 155   xerces-2.12.2      OPAL      RTA  edges-with-callsite-line-numbers
# 161   xerces-2.12.2      OPAL      CTA  edges-with-callsite-line-numbers
# 176   xerces-2.12.2      OPAL      FTA  edges-with-callsite-line-numbers
# 182   xerces-2.12.2      Doop    0-CFA  edges-with-callsite-line-numbers
# 170   xerces-2.12.2      OPAL      CHA  edges-with-callsite-line-numbers
# 194   xerces-2.12.2   ValueCG     fast  edges-with-callsite-line-numbers
# 188   xerces-2.12.2   ValueCG  precise  edges-with-callsite-line-numbers
#
#       package  true_positive  false_positive  false_negative  precision  \
# 338   package             38             134            5179   0.220930
# 332   package             38             106            5179   0.263889
# 200   package             66              99            5151   0.400000
# 212   package             91              52            5126   0.636364
# 224   package             91              52            5126   0.636364
# 242   package             91              52            5126   0.636364
# 248   package             91              52            5126   0.636364
# 218   package             94              52            5123   0.643836
# 230   package             94              52            5123   0.643836
# 236   package             94              52            5123   0.643836
# 260   package             94              52            5123   0.643836
# 206   package           3977           98300            1240   0.038885
# 254   package           4439           73672             778   0.056829
# 290   package           4865           73540             352   0.062050
# 326   package           4478           60602             739   0.068808
# 308   package           4348           48628             869   0.082075
# 314   package           4306           32317             911   0.117576
# 278   package           4756           26639             461   0.151489
# 302   package           4079           12233            1138   0.250061
# 296   package           2230            3249            2987   0.407009
# 320   package           3597            7563            1620   0.322312
# 272   package           4556            7546             661   0.376467
# 284   package           4556            7518             661   0.377340
# 266   package           4556            7086             661   0.391342
# 638   package            135            4977           20045   0.026408
# 632   package            138            3124           20042   0.042305
# 494   package           1002            5803           19178   0.147245
# 572   package           1208            5296           18972   0.185732
# 548   package          19665          368145             515   0.050708
# 518   package           1148            1928           19032   0.373212
# 536   package           1148            1928           19032   0.373212
# 506   package           1150            1931           19030   0.373255
# 542   package           1150            1931           19030   0.373255
# 554   package           1160            2071           19020   0.359022
# 530   package           1160            2067           19020   0.359467
# 524   package           1163            2123           19017   0.353926
# 512   package           1167            2145           19013   0.352355
# 578   package           1177            2102           19003   0.358951
# 560   package           1177            2083           19003   0.361043
# 566   package           1194            2128           18986   0.359422
# 590   package           1823            3210           18357   0.362209
# 500   package          16368          185958            3812   0.080899
# 626   package          16887          133717            3293   0.112128
# 608   package          14693          100143            5487   0.127948
# 584   package          19654          119950             526   0.140784
# 614   package          14401           73278            5779   0.164247
# 620   package          14328           41051            5852   0.258726
# 602   package          18749           30975            1431   0.377061
# 596   package          12604           12450            7576   0.503073
# 149   package            104           10698           23414   0.009628
# 143   package            105            3611           23413   0.028256
# 5     package            984            5005           22534   0.164301
# 83    package           1211            9040           22307   0.118135
# 29    package           1152            3100           22366   0.270931
# 47    package           1152            3100           22366   0.270931
# 17    package           1152            3099           22366   0.270995
# 53    package           1152            3099           22366   0.270995
# 35    package           1183            3529           22335   0.251061
# 23    package           1187            3569           22331   0.249579
# 65    package           1178            3324           22340   0.261661
# 41    package           1178            3312           22340   0.262361
# 89    package           1195            2358           22323   0.336335
# 77    package           1197            2398           22321   0.332962
# 71    package           1195            2280           22323   0.343885
# 11    package          18709          245509            4809   0.070809
# 137   package          19563          172438            3955   0.101890
# 119   package          16917          128454            6601   0.116371
# 59    package          22674          165318             844   0.120612
# 125   package          16877           89693            6641   0.158365
# 95    package          22719          124397             799   0.154429
# 131   package          16872           58895            6646   0.222683
# 101   package          19471           51755            4047   0.273369
# 107   package          13899           15528            9619   0.472321
# 113   package          21025           34493            2493   0.378706
# 1082  package            188            2596            2068   0.067529
# 1088  package            188            1933            2068   0.088637
# 950   package           1929            5220             327   0.269828
# 944   package           1874            2724             382   0.407569
# 998   package           2139            3105             117   0.407895
# 1034  package           1659            1845             597   0.473459
# 1046  package           1601            1187             655   0.574247
# 1076  package           1921            1615             335   0.543269
# 1058  package           1921            1612             335   0.543731
# 1064  package           1921            1499             335   0.561696
# 1070  package           1921            1443             335   0.571046
# 1040  package           1923             884             333   0.685073
# 1022  package           2081            1086             175   0.657089
# 1052  package           2040             747             216   0.731970
# 1016  package           2081             714             175   0.744544
# 1010  package           2081             703             175   0.747486
# 1028  package           2081             703             175   0.747486
# 974   package           2040             634             216   0.762902
# 980   package           2051             632             205   0.764443
# 1004  package           2051             632             205   0.764443
# 962   package           2054             634             202   0.764137
# 956   package           2051             627             205   0.765870
# 968   package           2051             627             205   0.765870
# 986   package           2051             627             205   0.765870
# 992   package           2051             627             205   0.765870
# 488   package           1140           31988            7248   0.034412
# 482   package           1140           11977            7248   0.086910
# 350   package           7528           74178             860   0.092135
# 398   package           8269           61094             119   0.119213
# 434   package           8258           39599             130   0.172556
# 476   package           7876           35372             512   0.182112
# 458   package           7876           31332             512   0.200877
# 344   package           7205           18348            1183   0.281963
# 464   package           7875           18911             513   0.293997
# 422   package           8271           20243             117   0.290068
# 470   package           7875            8719             513   0.474569
# 446   package           7106            5063            1282   0.583943
# 452   package           7416            5508             972   0.573816
# 440   package           7862            5621             526   0.583105
# 368   package           7087            4014            1301   0.638411
# 386   package           7106            4016            1282   0.638914
# 356   package           7115            4016            1273   0.639206
# 392   package           7115            4016            1273   0.639206
# 362   package           8088            5105             300   0.613052
# 374   package           8078            5081             310   0.613876
# 404   package           7767            4561             621   0.630029
# 380   package           7761            4523             627   0.631797
# 416   package           8270            4666             118   0.639301
# 428   package           8270            4659             118   0.639647
# 410   package           8270            4578             118   0.643680
# 938   package            622           30083            7319   0.020257
# 932   package            593            8888            7348   0.062546
# 800   package           7214           97856             727   0.068659
# 848   package           7790           87061             151   0.082129
# 926   package           7341           55182             600   0.117413
# 884   package           7766           54346             175   0.125032
# 908   package           7163           47920             778   0.130040
# 872   package           4300           17115            3641   0.200794
# 914   package           7139           28694             802   0.199230
# 920   package           3988            7414            3953   0.349763
# 794   package           3810            6442            4131   0.371635
# 890   package           3975            5626            3966   0.414019
# 836   package           3618            3375            4323   0.517375
# 818   package           3618            3369            4323   0.517819
# 806   package           3641            3385            4300   0.518218
# 842   package           3641            3385            4300   0.518218
# 812   package           4166            4401            3775   0.486285
# 824   package           4164            4302            3777   0.491850
# 830   package           4118            3868            3823   0.515652
# 854   package           4118            3868            3823   0.515652
# 866   package           4296            4048            3645   0.514861
# 878   package           4296            4036            3645   0.515602
# 860   package           4295            3884            3646   0.525125
# 902   package           6812            6033            1129   0.530323
# 896   package           6617            5602            1324   0.541534
# 1100  package            369          222391             107   0.001656
# 1232  package             74           29817             402   0.002476
# 1184  package            412          159873              64   0.002570
# 1226  package             74           22938             402   0.003216
# 1220  package            376           82797             100   0.004521
# 1202  package            376           65116             100   0.005741
# 1172  package            412           63158              64   0.006481
# 1148  package            412           62692              64   0.006529
# 1208  package            376           49849             100   0.007486
# 1094  package            369           46035             107   0.007952
# 1214  package            376           31058             100   0.011962
# 1112  package            411           29501              65   0.013740
# 1196  package            411           29294              65   0.013836
# 1124  package            410           25623              66   0.015749
# 1166  package            412           24705              64   0.016403
# 1178  package            412           24491              64   0.016544
# 1160  package            408           22398              68   0.017890
# 1190  package            395           10118              81   0.037573
# 1130  package            379            6870              97   0.052283
# 1154  package            379            6870              97   0.052283
# 1106  package            378            6584              98   0.054295
# 1136  package            378            6584              98   0.054295
# 1142  package            378            6584              98   0.054295
# 1118  package            378            6562              98   0.054467
# 644   package              0               0            5076   0.000000
# 656   package              0               0            5076   0.000000
# 662   package              0               0            5076   0.000000
# 674   package              0               0            5076   0.000000
# 680   package              0               0            5076   0.000000
# 692   package              0               0            5076   0.000000
# 704   package              0               0            5076   0.000000
# 710   package              0               0            5076   0.000000
# 716   package              0               0            5076   0.000000
# 722   package              0               0            5076   0.000000
# 728   package              0               0            5076   0.000000
# 734   package              0             255            5076   0.000000
# 740   package              0               0            5076   0.000000
# 770   package              0               0            5076   0.000000
# 782   package              0               0            5076   0.000000
# 788   package              0               0            5076   0.000000
# 650   package           1014           72508            4062   0.013792
# 776   package           4493          126079             583   0.034410
# 698   package           4853          133609             223   0.035049
# 758   package           4339           79945             737   0.051481
# 764   package           4337           58452             739   0.069073
# 746   package            691            2370            4385   0.225743
# 752   package           4081           37234             995   0.098778
# 686   package           1533            5367            3543   0.222174
# 668   package           1533            5343            3543   0.222949
# 155   package              0               0            5103   0.000000
# 161   package              0               0            5103   0.000000
# 176   package              0               0            5103   0.000000
# 182   package              0               0            5103   0.000000
# 170   package           4905          138252             198   0.034263
# 194   package           4242           32930             861   0.114118
# 188   package           2143            3938            2960   0.352409
#
#         recall  f1-score
# 338   0.007284  0.014103
# 332   0.007284  0.014176
# 200   0.012651  0.024526
# 212   0.017443  0.033955
# 224   0.017443  0.033955
# 242   0.017443  0.033955
# 248   0.017443  0.033955
# 218   0.018018  0.035055
# 230   0.018018  0.035055
# 236   0.018018  0.035055
# 260   0.018018  0.035055
# 206   0.762316  0.073995
# 254   0.850872  0.106543
# 290   0.932528  0.116357
# 326   0.858348  0.127402
# 308   0.833429  0.149434
# 314   0.825379  0.205832
# 278   0.911635  0.259806
# 302   0.781867  0.378931
# 296   0.427449  0.416978
# 320   0.689477  0.439275
# 272   0.873299  0.526127
# 284   0.873299  0.526979
# 266   0.873299  0.540483
# 638   0.006690  0.010675
# 632   0.006838  0.011774
# 494   0.049653  0.074263
# 572   0.059861  0.090541
# 548   0.974480  0.096399
# 518   0.056888  0.098727
# 536   0.056888  0.098727
# 506   0.056987  0.098878
# 542   0.056987  0.098878
# 554   0.057483  0.099099
# 530   0.057483  0.099116
# 524   0.057631  0.099122
# 512   0.057830  0.099353
# 578   0.058325  0.100345
# 560   0.058325  0.100427
# 566   0.059167  0.101608
# 590   0.090337  0.144608
# 500   0.811100  0.147124
# 626   0.836819  0.197759
# 608   0.728097  0.217648
# 584   0.973935  0.246007
# 614   0.713627  0.267034
# 620   0.710010  0.379253
# 602   0.929088  0.536421
# 596   0.624579  0.557280
# 149   0.004422  0.006061
# 143   0.004465  0.007711
# 5     0.041840  0.066696
# 83    0.051492  0.071723
# 29    0.048984  0.082967
# 47    0.048984  0.082967
# 17    0.048984  0.082970
# 53    0.048984  0.082970
# 35    0.050302  0.083812
# 23    0.050472  0.083964
# 65    0.050089  0.084083
# 41    0.050089  0.084119
# 89    0.050812  0.088286
# 77    0.050897  0.088297
# 71    0.050812  0.088541
# 11    0.795518  0.130043
# 137   0.831831  0.181543
# 119   0.719321  0.200333
# 59    0.964113  0.214401
# 125   0.717621  0.259471
# 95    0.966026  0.266289
# 131   0.717408  0.339870
# 101   0.827919  0.411023
# 107   0.590994  0.525035
# 113   0.893996  0.532036
# 1082  0.083333  0.074603
# 1088  0.083333  0.085904
# 950   0.855053  0.410207
# 944   0.830674  0.546834
# 998   0.948138  0.570400
# 1034  0.735372  0.576042
# 1046  0.709663  0.634814
# 1076  0.851507  0.663329
# 1058  0.851507  0.663672
# 1064  0.851507  0.676885
# 1070  0.851507  0.683630
# 1040  0.852394  0.759629
# 1022  0.922429  0.767472
# 1052  0.904255  0.809042
# 1016  0.922429  0.823995
# 1010  0.922429  0.825794
# 1028  0.922429  0.825794
# 974   0.904255  0.827586
# 980   0.909131  0.830532
# 1004  0.909131  0.830532
# 962   0.910461  0.830906
# 956   0.909131  0.831374
# 968   0.909131  0.831374
# 986   0.909131  0.831374
# 992   0.909131  0.831374
# 488   0.135908  0.054919
# 482   0.135908  0.106022
# 350   0.897473  0.167114
# 398   0.985813  0.212705
# 434   0.984502  0.293644
# 476   0.938960  0.305058
# 458   0.938960  0.330952
# 344   0.858965  0.424560
# 464   0.938841  0.447774
# 422   0.986052  0.448268
# 470   0.938841  0.630454
# 446   0.847163  0.691346
# 452   0.884120  0.695946
# 440   0.937291  0.718943
# 368   0.844897  0.727282
# 386   0.847163  0.728447
# 356   0.848236  0.729033
# 392   0.848236  0.729033
# 362   0.964235  0.749548
# 374   0.963042  0.749803
# 404   0.925966  0.749855
# 380   0.925250  0.750871
# 416   0.985932  0.775652
# 428   0.985932  0.775907
# 410   0.985932  0.778866
# 938   0.078328  0.032190
# 932   0.074676  0.068075
# 800   0.908450  0.127669
# 848   0.980985  0.151568
# 926   0.924443  0.208362
# 884   0.977962  0.221718
# 908   0.902027  0.227310
# 872   0.541494  0.292955
# 914   0.899005  0.326175
# 920   0.502204  0.412346
# 794   0.479788  0.418842
# 890   0.500567  0.453198
# 836   0.455610  0.484532
# 818   0.455610  0.484727
# 806   0.458506  0.486537
# 842   0.458506  0.486537
# 812   0.524619  0.504725
# 824   0.524367  0.507588
# 830   0.518574  0.517109
# 854   0.518574  0.517109
# 866   0.540990  0.527602
# 878   0.540990  0.527991
# 860   0.540864  0.532878
# 902   0.857826  0.655441
# 896   0.833270  0.656448
# 1100  0.775210  0.003306
# 1232  0.155462  0.004874
# 1184  0.865546  0.005126
# 1226  0.155462  0.006301
# 1220  0.789916  0.008990
# 1202  0.789916  0.011399
# 1172  0.865546  0.012866
# 1148  0.865546  0.012960
# 1208  0.789916  0.014832
# 1094  0.775210  0.015742
# 1214  0.789916  0.023566
# 1112  0.863445  0.027050
# 1196  0.863445  0.027236
# 1124  0.861345  0.030933
# 1166  0.865546  0.032196
# 1178  0.865546  0.032468
# 1160  0.857143  0.035049
# 1190  0.829832  0.071890
# 1130  0.796218  0.098123
# 1154  0.796218  0.098123
# 1106  0.794118  0.101640
# 1136  0.794118  0.101640
# 1142  0.794118  0.101640
# 1118  0.794118  0.101942
# 644   0.000000  0.000000
# 656   0.000000  0.000000
# 662   0.000000  0.000000
# 674   0.000000  0.000000
# 680   0.000000  0.000000
# 692   0.000000  0.000000
# 704   0.000000  0.000000
# 710   0.000000  0.000000
# 716   0.000000  0.000000
# 722   0.000000  0.000000
# 728   0.000000  0.000000
# 734   0.000000  0.000000
# 740   0.000000  0.000000
# 770   0.000000  0.000000
# 782   0.000000  0.000000
# 788   0.000000  0.000000
# 650   0.199764  0.025802
# 776   0.885146  0.066245
# 698   0.956068  0.067620
# 758   0.854807  0.097113
# 764   0.854413  0.127813
# 746   0.136131  0.169841
# 752   0.803980  0.175939
# 686   0.302009  0.256012
# 668   0.302009  0.256526
# 155   0.000000  0.000000
# 161   0.000000  0.000000
# 176   0.000000  0.000000
# 182   0.000000  0.000000
# 170   0.961199  0.066168
# 194   0.831276  0.200686
# 188   0.419949  0.383226

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[(df['scope'] == 'edges') & (df['package'] == 'package') & (df['framework'] == 'ValueCG')])
# Out:
#     project framework     algo  scope  package  true_positive  false_positive  \
# 574   axion   ValueCG     fast  edges  package              3               0
# 568   axion   ValueCG  precise  edges  package              3               0
# 280   batik   ValueCG     fast  edges  package              4               0
# 274   batik   ValueCG  precise  edges  package              4               0
# 412  hsqldb   ValueCG     fast  edges  package              4               0
# 406  hsqldb   ValueCG  precise  edges  package              4               0
# 736   jasml   ValueCG     fast  edges  package              6               0
# 730   jasml   ValueCG  precise  edges  package              6               0
# 124  xerces   ValueCG     fast  edges  package              0               0
# 118  xerces   ValueCG  precise  edges  package              0               0
#
#      false_negative  precision    recall  f1-score
# 574            3878        1.0  0.000773  0.001545
# 568            3878        1.0  0.000773  0.001545
# 280           13033        1.0  0.000307  0.000613
# 274           13033        1.0  0.000307  0.000613
# 412           13589        1.0  0.000294  0.000588
# 406           13589        1.0  0.000294  0.000588
# 736             968        1.0  0.006160  0.012245
# 730             968        1.0  0.006160  0.012245
# 124            3062        0.0  0.000000  0.000000
# 118            3062        0.0  0.000000  0.000000

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df[(df['scope'] == 'edges-with-callsite-line-numbers') & (df['package'] == 'package')])

# %%
df = data.reset_index()
display(df[(df['project'] == 'jasml') & (df['framework'] == 'WALA') & (df['scope'] == 'edge') & (df['package'] == 'package') & (df['metric'] == 'Static CG Size')])
display(df[(df['project'] == 'jasml') & (df['framework'] == 'WALA') & (df['scope'] == 'edge') & (df['package'] == 'package') & (df['metric'] == 'Recall')])

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method']:
    for package in ['package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["project"] == "axion") & (df["framework"] == "WALA")],
                             #row='project',
                             #row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.4,
                             aspect=1.6,
                             gridspec_kws={"wspace":0.5, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           #hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6,
                           dodge=True)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")

        grid.set_yticklabels(["  CHA", "  RTA", "0-CFA"], rotation=0, verticalalignment="center", fontsize=18)
        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        grid.set(xlabel=None)
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        #grid.fig.tight_layout()
        #pyplot.tight_layout()
        #grid.add_legend(ncols=2)
        #sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.127), ncols=1)
        pyplot.savefig('/out/axion-wala-method-package.pdf', dpi=300, bbox_inches="tight")
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['edge']:
    for package in ['all']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["algo"] == "CHA") & (df["framework"] != "Soot") & (df["framework"] != "Doop")],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1,
                             aspect=2.6,
                             gridspec_kws={"wspace":0.25, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA'],
                           #order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: "0%" if(x == 0) else str(round(x, 1)) + "%"))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}M'.format(int(x/1000000))))

            bar_cnt = 1
            special = [5,6,11,12,17,18,23,24]
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                
                for container in ax.containers:
                    
                    for bar in container:
                        if bar_cnt in special:
                            ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(-33, -12.5), color="white", textcoords="offset points")
                        else:
                            ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")
                        bar_cnt = bar_cnt + 1

        grid.despine(left=True, bottom=True)
        grid.set(xlabel=None)
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        grid.fig.tight_layout()
        pyplot.tight_layout()
        grid.add_legend(ncols=3)
        sns.move_legend(grid, "lower left", bbox_to_anchor=(0.23,0.32), ncols=1)
        pyplot.savefig('/out/cha-edge-all.pdf', dpi=300)
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['edge']:
    for package in ['all']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["algo"] == "0-CFA")],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.5,
                             aspect=1.7,
                             gridspec_kws={"wspace":0.25, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Doop'],
                           #order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))

            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        trunc = (human_format(bar.get_width()) == "605.3K")
                        ax.annotate(human_format(bar.get_width()), size=14, color = "white" if trunc else "black", xy=(bar.get_width(),bar.xy[1]), xytext=(-46 if trunc else 1.3, -12.5), textcoords="offset points")

        grid.despine(left=True, bottom=True)
        grid.set(xlabel=None)
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        grid.fig.tight_layout()
        pyplot.tight_layout()
        grid.add_legend(ncols=3)
        sns.move_legend(grid, "lower right", bbox_to_anchor=(0.91,0.425), ncols=1)
        pyplot.savefig('/out/0cfa-only.pdf', dpi=300)
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
rcParams["axes.labelsize"] = 18
df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method']:
    for package in ['package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package) & (df["project"] == "xerces") & (df["metric"] != "Precision")],
                             #row='project',
                             #row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=5,
                             aspect=0.7,
                             gridspec_kws={"wspace":0.5, "hspace":0.0})
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind',
                           width=0.6,
                           dodge=True)
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            #axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#ABAEAC', linewidth=1)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=14, xy=(bar.get_width(),bar.xy[1]), xytext=(1.3, -12.5), textcoords="offset points")

        grid.set_yticklabels(["  CHA", "  RTA", "0-CFA"], rotation=90, verticalalignment="center", fontsize=18)
        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        grid.set(xlabel=None)
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
        #grid.fig.tight_layout()
        #pyplot.tight_layout()
        grid.add_legend(ncols=2)
        sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.127), ncols=1)
        pyplot.savefig('/out/xerces-filtered.pdf', dpi=300, bbox_inches="tight")
        pyplot.show()

# %%
import seaborn as sns
from matplotlib import pyplot, ticker, rcParams
import math

rcParams['pdf.fonttype'] = 42

sns.set_theme(style="whitegrid", palette='colorblind')
sns.color_palette("colorblind")

def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.1f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

df = data.reindex(pd.MultiIndex.from_product(data.index.levels)).reset_index()
# df = data.reset_index()
nan_num = 0.00001
for scope in ['method', 'edge']:
    for package in ['all', 'package']:
        grid = sns.FacetGrid(df[(df["scope"] == scope) & (df["package"] == package)],
                             row='project',
                             row_order=['axion', 'batik', 'jasml', 'xerces'],
                             col='metric',
                             col_order=['Precision', 'Recall', 'Static CG Size'],
                             sharex="col",
                             margin_titles=True,
                             legend_out=False,
                             height=1.5,
                             aspect=1.7)
        grid.map_dataframe(sns.barplot,
                           y='algo',
                           x='metric_value',
                           hue='framework',
                           hue_order=['OPAL', 'WALA', 'Soot', 'Doop'],
                           order=['CHA', 'RTA', '0-CFA'],
                           palette='colorblind')
        # grid.despine()
        for axis in grid.axes:
            axis[0].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[1].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:d}%'.format(int(x))))
            axis[2].xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '0' if x == 0 else '{:d}K'.format(int(x/1000))))
            for ax in axis:
                ax.grid(which='major', color='#DDDDDD', linewidth=0.8)
                ax.minorticks_on()
                for container in ax.containers:
                    for bar in container:
                        ax.annotate(human_format(bar.get_width()), size=6, xy=(bar.get_width(),bar.xy[1]), xytext=(1, -4.5), textcoords="offset points")
                    #labels = ['' if v == nan_num else human_format(v) for v in container.datavalues]
                    #ax.bar_label(container,labels=labels,size=7)

        grid.despine(left=True, bottom=True)
        grid.set_axis_labels(scope.capitalize() + '/' + package.capitalize(), "Algorithm")
        grid.set_ylabels(label='')
        if scope == 'method':
            grid.set_titles(col_template="{col_name}", row_template="")
        if scope == 'edge':
            grid.set_titles(col_template="{col_name}", row_template="{row_name}")
            grid.set_yticklabels([])
            if package == 'package':
                grid.add_legend()
                sns.move_legend(grid, "lower right", bbox_to_anchor=(0.92,0.325))
        grid.fig.tight_layout()
        pyplot.tight_layout()
        pyplot.savefig("/out/" + scope+'-'+package+'.pdf', dpi=300)
        pyplot.show()
